# %%
import requests
from bs4 import BeautifulSoup
# タイトルを取得する対象のURL
url = 'https://news.yahoo.co.jp/articles/205a716f18096b9be9bf69124acfda44e2f577e5'
# GETリクエストを送信し、HTMLを取得する
response = requests.get(url)
# HTMLを解析する
soup = BeautifulSoup(response.text, 'html.parser')
# タイトルの要素を取得する
# CSSセレクタを使用して、本文を取得する
mainText_element = soup.select_one('#uamods > div > div > p')
##print(title_element)
# 本文のテキストを取得する
main_text = mainText_element.text
print(main_text)
# Out:
# 北方領土の表示をめぐり、日本政府が世界地図の修正を求めたことに対し、ロシア側が「ばかげたことだ」と反発しました。
#
# 各国の面積をより正確に表す「イコールアース図法」の世界地図では、北方領土がロシア領と同じ色で表示されていたため、日本政府が修正を求めていました。
#
# その後、日本語版では北方領土が日本と同じ色に変更されましたが、「ロシアが実効支配し、日本が領有権を主張」とする注釈や、ロシア語版での表示は変更されていません。
#
# こうした中、ロシア国営タス通信によりますと、ウシャコフ大統領補佐官は11日、日本政府の修正要求について、「ばかげたことだ」と述べました。
#
# 北方領土をめぐっては、ロシアは自国領だとする立場を崩していません。
